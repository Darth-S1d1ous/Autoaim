# %%
import cv2
from ultralytics import YOLO

# %%
model = YOLO("../models/best.pt")

# %%
results = model('../train/data/images/test/scene_25/000001.jpg')
results[0].show()
# Out:
# image 1/1 d:\Autoaim\scripts\..\train\data\images\test\scene_25\000001.jpg: 544x960 219 heads, 63.9ms
# Speed: 6.1ms preprocess, 63.9ms inference, 3.7ms postprocess per image at shape (1, 3, 544, 960)
