# %%
from ultralytics import YOLO

# %%
model = YOLO('../models/best.pt')  # load a custom model

# %%
model.export(format='onnx')
# Out:
# Ultralytics 8.4.8  Python-3.10.17 torch-2.5.1+cu121 CPU (13th Gen Intel Core i9-13900H)
# Model summary (fused): 73 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#
# PyTorch: starting from '..\models\best.pt' with input shape (1, 3, 960, 960) BCHW and output shape(s) (1, 5, 18900) (21.5 MB)
#
# ONNX: starting export with onnx 1.16.1 opset 19...
# ONNX: slimming with onnxslim 0.1.82...
# ONNX: export success  5.2s, saved as '..\models\best.onnx' (42.9 MB)
#
# Export complete (6.9s)
# Results saved to D:\Autoaim\models
# Predict:         yolo predict task=detect model=..\models\best.onnx imgsz=960
# Validate:        yolo val task=detect model=..\models\best.onnx imgsz=960 data=/media/disk3/wenzhuang/Autoaim/train/data/data.yaml
# Visualize:       https://netron.app
# '..\\models\\best.onnx'

# %%
model.export(format='engine')
# Out:
# WARNING TensorRT requires GPU export, automatically assigning device=0
# Ultralytics 8.4.8  Python-3.10.17 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# Model summary (fused): 73 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#
# PyTorch: starting from '..\models\best.pt' with input shape (1, 3, 960, 960) BCHW and output shape(s) (1, 5, 18900) (21.5 MB)
#
# ONNX: starting export with onnx 1.16.1 opset 17...
# ONNX: slimming with onnxslim 0.1.82...
# ONNX: export success  2.1s, saved as '..\models\best.onnx' (42.9 MB)
# ERROR TensorRT: export failure 2.1s: No module named 'tensorrt'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\lvwen\anaconda3\envs\isaaclab\lib\site-packages\ultralytics\engine\exporter.py:1006, in Exporter.export_engine(self, dla, prefix)
#    1005 try:
# -> 1006     import tensorrt as trt
#    1007 except ImportError:
#
# ModuleNotFoundError: No module named 'tensorrt'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 model.export(format='engine')
#
# File c:\Users\lvwen\anaconda3\envs\isaaclab\lib\site-packages\ultralytics\engine\model.py:710, in Model.export(self, **kwargs)
#     702 custom = {
#     703     "imgsz": self.model.args["imgsz"],
#     704     "batch": 1,
#    (...)
#     707     "verbose": False,
#     708 }  # method defaults
#     709 args = {**self.overrides, **custom, **kwargs, "mode": "export"}  # highest priority args on the right
# --> 710 return Exporter(overrides=args, _callbacks=self.callbacks)(model=self.model)
#
# File c:\Users\lvwen\anaconda3\envs\isaaclab\lib\site-packages\ultralytics\engine\exporter.py:576, in Exporter.__call__(self, model)
#     574     f[0] = self.export_torchscript()
#     575 if engine:  # TensorRT required before ONNX
# --> 576     f[1] = self.export_engine(dla=dla)
#     577 if onnx:  # ONNX
#     578     f[2] = self.export_onnx()
#
# File c:\Users\lvwen\anaconda3\envs\isaaclab\lib\site-packages\ultralytics\engine\exporter.py:249, in try_export.<locals>.outer_func(*args, **kwargs)
#     247 except Exception as e:
#     248     LOGGER.error(f"{prefix} export failure {dt.t:.1f}s: {e}")
# --> 249     raise e
#
# File c:\Users\lvwen\anaconda3\envs\isaaclab\lib\site-packages\ultralytics\engine\exporter.py:241, in try_export.<locals>.outer_func(*args, **kwargs)
#     239 try:
#     240     with Profile() as dt:
# --> 241         f = inner_func(*args, **kwargs)  # exported file/dir or tuple of (file/dir, *)
#     242     path = f if isinstance(f, (str, Path)) else f[0]
#     243     mb = file_size(path)
#
# File c:\Users\lvwen\anaconda3\envs\isaaclab\lib\site-packages\ultralytics\engine\exporter.py:1011, in Exporter.export_engine(self, dla, prefix)
#    1009         cuda_version = torch.version.cuda.split(".")[0]
#    1010         check_requirements(f"tensorrt-cu{cuda_version}>7.0.0,!=10.1.0")
# -> 1011     import tensorrt as trt
#    1012 check_version(trt.__version__, ">=7.0.0", hard=True)
#    1013 check_version(trt.__version__, "!=10.1.0", msg="https://github.com/ultralytics/ultralytics/pull/14239")
#
# ModuleNotFoundError: No module named 'tensorrt'
