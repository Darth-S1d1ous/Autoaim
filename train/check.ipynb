# %%
import cv2

# %% [markdown]
# ### Check image size

# %%
img = cv2.imread("D:/GTA_Head/GTA_Head/train/scene_01/img1/000001.jpg")
print("image shape: ", img.shape)
# Out:
# image shape:  (1080, 1920, 3)
